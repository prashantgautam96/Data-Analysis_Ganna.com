# %% [markdown]
# <a href="https://colab.research.google.com/github/prashantgautam96/Data-Analysis_Ganna.com/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AshishJangra27/Gaana-Data-Analysis
# Out:
# Cloning into 'Gaana-Data-Analysis'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 23 (delta 7), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (23/23), done.

# %% [markdown]
# # 1. Data Loading

# %%
import pandas as pd
from tqdm import tqdm

df = pd.read_csv('Gaana-Data-Analysis/songs.csv')

# %%
df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                       /unke-dekhe-se     Urdu
# ...

# %% [markdown]
# <!-- check null values -->

# %% [markdown]
# # 2. Data Pre_Processing

# %%
df.isnull().sum()
# Out:
# name         0
# singer       0
# singer_id    0
# duration     0
# link         0
# language     0
# dtype: int64

# %% [markdown]
# <!-- data preprocessing -->
# .Dealing with duration

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df['duration']
# Out:
# 0        05:00
# 1        06:26
# 2        03:41
# 3        04:26
# 4        05:39
#          ...
# 41350    03:23
# 41351    03:56
# 41352    07:36
# 41353    04:29
# 41354    03:22
# Name: duration, Length: 41355, dtype: object

# %%
duration_list=[]
for duration in df['duration']:
  # print(duration,type(duration))
  m=int(duration.split(':')[0])
  s= int(duration.split(':')[1])
  sec=m*60+s
  duration_list.append(sec)
df['duration']=duration_list
df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id  duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1       300
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1       386
# 2                       /artist/jagjeet-singh-1       221
# 3                          /artist/chitra-singh       266
# 4                       /artist/jagjeet-singh-1       339
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# ...

# %% [markdown]
# # 3. Data Analysis
# ### 3.1 Average Duration of a Songs throughouth the dataset

# %%
df['duration']
# Out:
# 0        300
# 1        386
# 2        221
# 3        266
# 4        339
#         ...
# 41350    203
# 41351    236
# 41352    456
# 41353    269
# 41354    202
# Name: duration, Length: 41355, dtype: int64

# %%
df['duration'].sum()/len(df['duration'])
# Out:
# 295.3130697618184

# %% [markdown]
# 3.2  What languages of songs do we have in datasets

# %%
set(df['language'])
# Out:
# {'Assamese',
#  'Bengali',
#  'Bhojpuri',
#  'Gujarati',
#  'Haryanvi',
#  'Hindi',
#  'Kannada',
#  'Malayalam',
#  'Marathi',
#  'Odia',
#  'Old',
#  'Punjabi',
#  'Rajasthani',
#  'Tamil',
#  'Telugu',
#  'Urdu'}

# %% [markdown]
# 3.3  How many languages we have

# %%
len(set(df['language']))
# Out:
# 16

# %% [markdown]
# 3.3 How may Punjabi songs are there?

# %%
c=0;
for i in df['language']:
  if(i=='Punjabi'):
      c+=1
print('Punjabi songs: ',c)
# Out:
# Punjabi songs  3818

# %%
df['language']=='Punjabi'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 41350    False
# 41351    False
# 41352    False
# 41353    False
# 41354    False
# Name: language, Length: 41355, dtype: bool

# %%
df[df['language']=='Punjabi']
# Out:
#                                              name  \
# 14236                          Pehle Lalkare Naal
# 14237                 Sharbat Wangu Ghut Bhar Lan
# 14238                              Jija Lak Minle
# 14239                            Laija Kithe Door
# 14240                        Das Meriya Dilwarave
# ...                                           ...
# 18049                                  I Love You
# 18050                         Aeh Dunya Lag Di Ae
# 18051  Nak Nathli Tey Akhan (From "Balocha Daku")
# 18052                       Main Kiyoon Na Tenoon
# 18053                            Jehra Karda Zulm
#
#                             singer  \
# 14236  Amar Singh Chamkila|Amarjot
# 14237  Amar Singh Chamkila|Amarjot
# 14238  Amar Singh Chamkila|Amarjot
# 14239  Amar Singh Chamkila|Amarjot
# 14240    Asha Bhosle|Mohammed Rafi
# ...                            ...
# 18049                 Nahid Akhtar
# 18050                   Noor Jehan
# ...

# %% [markdown]
# 3.5 Number of songs in Each language?

# %%
for lang in df['language'].unique():

  # c=0
  # for i in df['language']:
  #   if(i==lang):
  #     c+=1
  print(lang,len(df[df['language']==lang]))
# Out:
# Urdu 3116
# Gujarati 2115
# Tamil 4677
# Kannada 3559
# Rajasthani 541
# Haryanvi 228
# Punjabi 3818
# Hindi 4993
# Old 4993
# Malayalam 479
# Marathi 4699
# Telugu 4996
# Odia 940
# Bhojpuri 519
# Assamese 724
# Bengali 958

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %% [markdown]
# 3.6 Average duration of songs in each language?

# %%
for lang in df['language'].unique():
  print(lang,int(df[df['language']==lang]['duration'].mean()))
# Out:
# Urdu 407
# Gujarati 271
# Tamil 270
# Kannada 250
# Rajasthani 291
# Haryanvi 320
# Punjabi 324
# Hindi 307
# Old 307
# Malayalam 242
# Marathi 281
# Telugu 279
# Odia 257
# Bhojpuri 357
# Assamese 228
# Bengali 255

# %% [markdown]
# 3.7 How many unique singers are there in datasets?

# %%
all_singers=[]
for singers in df['singer']:
  all_singers += singers.split('|')
  print(singers.split('|'))
# Out:
# Streaming output truncated to the last 5000 lines.
# ['Ghanatasala']
# ['P. Susheela']
# ['S. P. Balasubrahmanyam', 'P. Susheela']
# ['P. Susheela']
# ['S.P.Charan']
# ['V. Ramakrishna']
# ['Ghanatasala', 'Padmavathi', 'P. Susheela', 'Srinivas']
# ['Ghanatasala', 'P. Susheela']
# ['Ghanatasala', 'Chorus']
# ['S. P. Balasubrahmanyam', 'P. Susheela']
# ['S. P. Balasubrahmanyam', 'P. Susheela']
# ['K J Yesudas', 'S. Janaki']
# ['P. Susheela', 'S. P. Balasubrahmanyam']
# ['S. P. Balasubrahmanyam']
# ['S. Janaki']
# ['G. Anand']
# ['Ghanatasala', 'P. Susheela']
# ['Ghanatasala', 'P Suhseela']
# ['K J Yesudas', 'P. Susheela']
# ['S. P. Balasubrahmanyam', 'P. Susheela']
# ['S. P. Balasubrahmanyam']
# ['Ghanatasala', 'P. Susheela']
# ['K J Yesudas']
# ['P. Susheela']
# ['Ghanatasala', 'S. P. Balasubrahmanyam', 'L.R. Eswari']
# ['S. P. Balasubrahmanyam', 'P. Susheela']
# ['P. Susheela']
# ['K. Veermani']
# ['P. Susheela', 'S. P. Balasubrahmanyam']
# ['S. Janaki', 'K J Yesudas']
# ...

# %%
len(set(all_singers))
# Out:
# 3940

# %% [markdown]
# 3.8  Who has the most number of songs?

# %%
data =[]

unique_singers = list(set(all_singers))

for i in (unique_singers):

  c=0
  for singers_ in df['singer']:
    if(i in singers_):
      c+=1
  data.append([i,c])

# %%
songs = pd.DataFrame(data,columns=['singer','songs'])
songs
# Out:
#                 singer  songs
# 0             Bupinder      1
# 1            S. Janski      3
# 2      Ajoy Chakrwarti      9
# 3     Shailender Singh     89
# 4            Manju Das      2
# ...                ...    ...
# 3935     Parag Chaliha      1
# 3936  Kasthuri Shankar      8
# 3937  Sanwar Lal Ranga      1
# 3938     J V Raghavulu      2
# 3939         Siddaramu      1
#
# [3940 rows x 2 columns]

# %%
len(data)
# Out:
# 3940

# %%
songs.sort_values(by='songs',ascending=False).head()
# Out:
#                       singer  songs
# 3263  S. P. Balasubrahmanyam   3659
# 2738                   Kumar   3270
# 503                  Susheel   3216
# 3841                Susheela   3215
# 2523             P. Susheela   3213

# %% [markdown]
# 3.9   Singers who played most number of songs in each language

# %%
for lang in df['language'].unique():
  df_= df[df['language']==lang]

  all_singers=[]
 
  for singers in df_['singer']:
    all_singers += singers.split('|')

  print(lang,len(set(all_singers)))
# Out:
# Urdu 385
# Gujarati 303
# Tamil 510
# Kannada 379
# Rajasthani 218
# Haryanvi 76
# Punjabi 636
# Hindi 515
# Old 515
# Malayalam 72
# Marathi 569
# Telugu 369
# Odia 243
# Bhojpuri 109
# Assamese 228
# Bengali 192

# %% [markdown]
# After that we can do same things which we performed during 3.8 task
